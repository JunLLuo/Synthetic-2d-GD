# %%
# %%latex
# The other dataset we tested on is a synthetic dataset where we generate 200 2D-Gaussian objects at random positions in an image with Gaussian noisy as background. The standard deviation of those 2D-Gaussian objects are in range 1 to 5 pixels. We save the coordinate of the mean (centre) of each Gaussian object after they are generated. The main difference between this dataset and the cell dataset is the Gaussian objects may overlap one another. We do exactly same experiment on this dataset: we train the UNet on one image of this 2D-Gaussian image with annotation, followed by self-training using \textit{nearby pixels threshold}. The results of applying our counting algorithm to the segmentation map of those 2D-Gaussian images are presented in Table 3. Since it's more challenging to count objects that may overlap, the TPR is 1-2% lower and the PPV is 2-3% lower than results for cells images. Figure below shows an example of result for counting on 2D-Gaussian image.
# Out:
# The other dataset we tested on is a synthetic dataset where we generate 200 2D-Gaussian objects at random positions in an image with Gaussian noisy as background. The standard deviation of those 2D-Gaussian objects are in range 1 to 5 pixels. We save the coordinate of the mean (centre) of each Gaussian object after they are generated. The main difference between this dataset and the cell dataset is the Gaussian objects may overlap one another. We do exactly same experiment on this dataset: we train the UNet on one image of this 2D-Gaussian image with annotation, followed by self-training using \textit{nearby pixels threshold}. The results of applying our counting algorithm to the segmentation map of those 2D-Gaussian images are presented in Table 3. Since it's more challenging to count objects that may overlap, the TPR is 1-2% lower and the PPV is 2-3% lower than results for cells images. Figure below shows an example of result for counting on 2D-Gaussian image.

# %%
from IPython.display import Image
import matplotlib.pyplot as plt
i = Image(filename='./images/2D-Gaussian.png')
i

# %%
print("A test sample for the counting on 2D-Gaussian synthetic images. Left: predictions. Right: ground truth centres. P:192, TP:183, FP:9, FN:17.")
# Out:
# A test sample for the counting on 2D-Gaussian synthetic images. Left: predictions. Right: ground truth centres. P:192, TP:183, FP:9, FN:17.
